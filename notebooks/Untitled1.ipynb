# %%
from __future__ import print_function, division
import pandas as pd
bp_data = pd.read_csv("HARARE FULL/tabula-NATIONAL ASSEMBLY HARARE RESULTS-0.csv", header=1)

# %%
bp_data
# Out:
#        Chirombe Oddrey Sydney  M         MDC -T   4409
# 0       Chitate Nelson Tendai  M    Independent    611
# 1               Gatsi Clayton  M            PRC    212
# 2     Gomwe Godwin Simbarashe  M        ZANU PF   8529
# 3               Lupemba Derek  M           CODE     69
# 4           Machingauta Costa  M  MDC -Alliance  28575
# 5    Mavunga Kudakwashe Evans  M    Independent     78
# 6              Muchakasi Mary  F            NPF     60
# 7               Mudoka Edmore  M           ZIPP     67
# 8               Murwira Taona  M    Independent     61
# 9   Musindo Evelyn Subuzikeni  F            NCA     68
# 10               Shoniwa Ruth  F  FREEDOM FRONT     44
# 11             Tavengwa Silas  M       MAAT ZIM     28

# %%
BUDIRIRO  
  CHITUNGWIZA NORTH  


for range(0-10):
